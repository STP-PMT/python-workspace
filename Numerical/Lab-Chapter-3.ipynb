# %%
#62011212109

# %%
import numpy as np
import matplotlib.pyplot as plt 
#plt.style.use('seaborn')

plt.plot([1,5,2,5,3])
plt.ylabel('Y-axis')
plt.xlabel('X-axis')
plt.show()

# %%
plt.plot([0,2],[0,2],'r--')
plt.show()

# %%
plt.plot([9,2,-2,5],'ro',[3,7,-2,4],'--r')
plt.show()

# %%
a = np.arange(0,5,0.5)
plt.plot(a,a,'r--',a,a**2,'g^',a,a**3,'bs')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 


lay1='y1 = 2x-5'
lay2='y2 = x-3'

x = np.linspace(-5,20)
y1=(2*x)-5
y2=x-3
plt.plot(x,y1,color='red',label =lay1)
plt.plot(x,y2,color='green',label =lay2)
plt.plot(2,-1,'bo')
plt.text(0,1,'(2,-1)',fontsize =15 )

plt.legend()
plt.show()

# %%
x = np.linspace(-10,10)
plt.figure()

plt.subplot(321)
plt.plot(x,np.cos(x),'r-')

plt.subplot(322)
plt.plot(x,np.sin(x),'g-')

plt.subplot(323)
plt.plot(x,np.tan(x),'b-')

plt.subplot(324)
plt.plot(x,-np.sin(x),'p-')

plt.subplot(325)
plt.plot(x,'y-')

plt.subplot(326)
plt.plot(x,-np.tan(x),'r--')

plt.show()

# %%
import matplotlib.image as img 
yoongi_img = img.imread('C:/Users/stppm/Downloads/WITH YOONGI.jpg')

plt.imshow(yoongi_img)
plt.axis('off')
plt.show()

# %%
A = np.array([[1,-2],[2,5]])
B= np.array([8,-11])

x = np.linalg.inv(A).dot(B)

print(x)
# Out:
# [ 2. -3.]

# %%
a = np.array([[2,2,-1,4],[0,2,-1,2],[2,-4,2,-4],[-1,-1,2,-2]])
b = np.array([17,11,-18,-10])
x = np.linalg.solve(a,b)
print(x)
# Out:
# [ 2.  4. -1.  1.]

# %%
n=1
c=0.01
print(0.5*n**2-3*n>=c*n**2)
print(0.5*n**2-3*n)
print('<=')
print(c*n**2)
# Out:
# True
# 4999700000.0
# <=
# 100000000.0
